# %%
print('Hello')
# Out:
# Hello

# %%
print ("Namastey India")
# Out:
# Namastey India

# %%
print("This is the third line")
# Out:
# This is the third line

# %%
print("*")
# Out:
# *

# %%
print("*")
print("**")
print("***")
print("****")
print("*****")
print("******")
print("*******#")
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******#

# %%
print("    *")
print("   **")
print("  ***")
print(" ****")
print("*****")
# Out:
#     *
#    **
#   ***
#  ****
# *****
