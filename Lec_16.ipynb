# %%
x = input(str("What is your name?")).lower()

print(x)
# Out:
# riya jain

# %%
x = input(str("What is your name?")).upper()

print(x)
# Out:
# RIYA JAIN

# %%
x = input(str("What is your name?")).capitalize()

print(x)
# Out:
# Riya jain

# %%
x = input(str("What is your name?")).title()

print(x)
# Out:
# Riya Jain

# %%
x = input(str("What is your name?")).swapcase()

print(x)
# Out:
# riYA jaIN

# %%
x = input(str("What is your name?")).islower()

print(x)
# Out:
# False

# %%
x = input(str("What is your name?")).isupper()

print(x)

# %%
x = input(str("What is your name?")).istitle()

print(x)

# %%
x = input(int()).isdigit()

print(x)
# Out:
# True

# %%
x = input(str("What is your name?")).isalpha()

print(x)
# Out:
# True

# %%
x = input("Enter your Password:").isalnum()

print(x)
# Out:
# False

# %%
x = input(str("Where do you live?")).strip()

print(x)
# Out:
# riya jain

# %%
x = input(str("Where do you live?")).lstrip('*')

print(x)
# Out:
# new delhi************

# %%
x = input(str("Where do you live?")).rstrip('*')

print(x)

# %%
x = input(str("Where do you live?")).startswith('R')

print(x)
# Out:
# False

# %%
x = input(str("Where do you live?")).endswith('n')

print(x)

# %%
x = input(str("Where do you live?")).count('s')

print(x)
# Out:
# 1

# %%
x = input(str("Where do you live?")).index('s')

print(x)
# Out:
# 2

# %%
x = "Riya jain junior"

x = x.replace('j','J')

print(x)
# Out:
# Riya Jain Junior
