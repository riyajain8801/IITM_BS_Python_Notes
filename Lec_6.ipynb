# %%
n = 10
print(n)
# Out:
# 10

# %%
r = 6.3
print(r)
# Out:
# 6.3

# %%
s = "riya"
print(s)
# Out:
# riya

# %%
print("n is of type:",type(n))
# Out:
# n is of type: <class 'int'>

# %%
print("r is of type:",type(r))
# Out:
# r is of type: <class 'float'>

# %%
print("s is of type:", type(s))
# Out:
# s is of type: <class 'str'>

# %% [markdown]
# Why there is a need to know datatypes? why does python needs to know what is the datatype?

# %% [markdown]
# Different types of datatypes require different amount of memory space

# %%
l = [10,20,30]
print(l[0])
# Out:
# 10

# %%
l = [10,20,30]
print(l[1])
# Out:
# 20

# %%
l = [10,20,30]
print(l[2])
# Out:
# 30

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
print(type(l[2]))
# Out:
# <class 'int'>
