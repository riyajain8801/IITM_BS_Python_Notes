# %%
print("Hello India")
# Out:
# Hello India

# %%
print("Hello World,","Hello India,", "Hi, Python Students,")
# Out:
# Hello World, Hello India, Hi, Python Students,

# %%
print(10)
# Out:
# 10

# %%
print(20.5)
# Out:
# 20.5

# %%
print("Hello India", 10, 20.5)
# Out:
# Hello India 10 20.5
