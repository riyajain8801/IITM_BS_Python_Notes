# %% [markdown]
# Replication

# %%
s = 'good! '
print(s*5)
# Out:
# good! good! good! good! good!

# %%
print(s*0)

# %%
print(s[3]*9)
# Out:
# ddddddddd

# %% [markdown]
# String comparison

# %%
x = "India"
print(x== "India")
print(x=='india')
# Out:
# True
# False

# %%
print("apple" > "one")
print("four" < "two")
# Out:
# False
# True

# %%
print("ab"<"az")
# Out:
# True

# %%
print("abcdef"< "abcde")
# Out:
# False

# %%
s = "python"
print(s[0])
print(s[1])
print(s[2])
print(s[3])
print(s[4])
print(s[5])
# Out:
# p
# y
# t
# h
# o
# n

# %% [markdown]
# Negative indexing

# %%
s = "python"
print(s[-1])
print(s[-2])
print(s[-3])
print(s[-4])
print(s[-5])
print(s[-6])
# Out:
# n
# o
# h
# t
# y
# p

# %%
s = "bsgdgsakhsahslfflkasckbbcbfkashkha"
print(s[33])
# Out:
# a

# %% [markdown]
# Length is the total no of characters. index starts with 0 therefore last index will be (length-1)

# %%
print(len(s))
# Out:
# 34
