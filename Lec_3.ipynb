# %%
print(10)
# Out:
# 10

# %%
a=10
print(a)
# Out:
# 10

# %%
b=20
print(b)
# Out:
# 20

# %%
print(a+b)
# Out:
# 30

# %%
print(a*b)
# Out:
# 200

# %%
a=10
print(a)
a=a+1
print(a)
a=a+1
print(a)
a=a+1
print(a)
# Out:
# 10
# 11
# 12
# 13

# %%
print("Enter a number:")
n = (input())
print(n)
# Out:
# Enter a number:
# 7

# %%
n=int(input("Enter a number"))
print(n)
print(n+1)
print(n+2)
print(n+3)
# Out:
# 100
# 101
# 102
# 103
