# %%
s = 'coffee'
t= 'bread'
print(s)
print(t)
print(s+t)
# Out:
# coffee
# bread
# coffeebread

# %%
print(s[0])
# Out:
# c

# %%
print(s[1])
# Out:
# o

# %%
print(s[0:1])
# Out:
# c

# %%
print(s[0:4])
# Out:
# coff

# %%
print(s[2:4])
# Out:
# ff

# %%
s = '123456789'
a= s[0]
b = s[4]
print(a)
print(b)
# Out:
# 1
# 5

# %%
print(a+b)
# Out:
# 15

# %%
s = '123456789'
a= int(s[0])
b = int(s[4])
print(a)
print(b)
# Out:
# 1
# 5

# %%
print(a+b)
# Out:
# 6

# %%
s = '123456789'
a= s[7]
b = s[3]
print(a)
print(b)
# Out:
# 8
# 4

# %%
print(int(a+b))
# Out:
# 84

# %%
print()
