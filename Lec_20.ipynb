# %%
import math

print(math.log(10))
print(math.sin(90))
print(math.sqrt(16))
print(math.factorial(5))
print(math.pow(10,5))
# Out:
# 2.302585092994046
# 0.8939966636005579
# 4.0
# 120
# 100000.0

# %%
import random 

a = random.random()
if a < 0.5:
  print('heads')
else:
  print('tails')
# Out:
# heads

# %%
import random 

a = random.randrange(1,7)
print(a)


b = random.randrange(1,7)
print(b)
total = a + b

print(total)
# Out:
# 6
# 2
# 8
