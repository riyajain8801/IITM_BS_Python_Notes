# %%
email = input("Please enter the email: ")
print(email)

for i in email:
  if (i =='@'):
    break 
  print(i, end="")
# Out:
# riya@
# riya

# %%
email = input("Please enter the email: ")
print(email)

for i in email:
  if (i =='@'):
    print('')
    continue
  print(i, end="")
# Out:
# riya@123
# riya
# 123

# %%
for x in range(15):
  if (x%3 == 0):
    print(x)
  else:
    pass
# Out:
# 0
# 3
# 6
# 9
# 12
