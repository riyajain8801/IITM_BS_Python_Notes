# %%
# If condition
# Let us consider the movie "Avengers", This is a 13+ movie.

birth_year= int(input("please enter your year of birth: "))

current_year = 2026

age = current_year-birth_year


if (age<13):
  print("you are underage! you can not watch this movie")
  print("wait until you are old enough to watch the movie")
else:
  print("you are old enough to watch avengers")
  print("have a nice time")
# Out:
# you are underage! you can not watch this movie
# wait until you are old enough to watch the movie
