# %%
print("It's a beautiful day")
# Out:
# It's a beautiful day

# %% [markdown]
# print ('It's a beautiful day') # Incorrect

# %%
print('It\'s a beautiful day')
# Out:
# It's a beautiful day

# %%
print("we are from \"IIT\" Madras")
# Out:
# we are from "IIT" Madras

# %%
print('My name is riya. I am from delhi')
# Out:
# My name is riya. I am from delhi

# %%
print('My name is riya. \t I am from delhi')
# Out:
# My name is riya. 	 I am from delhi

# %%
print('My name is riya. \t\t I am from delhi')
# Out:
# My name is riya. 		 I am from delhi

# %%
print('My name is riya.\nI am from delhi.')
# Out:
# My name is riya.
# I am from delhi.

# %%
x = "This is a string"
y = 'This is also a string'
z = '''First line
Second line 
Third line'''

print(x)
print(y)
print(z)
# Out:
# This is a string
# This is also a string
# First line
# Second line
# Third line

# %%
'''Triple quotes are used to write multi line commets like these.
Remember this'''
# Out:
# 'Triple quotes are used to write multi line commets like these.\nRemember this'
