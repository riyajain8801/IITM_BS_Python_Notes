# %%
roll = 5
Roll = 10
ROLL = 15

# %%
print(roll)
# Out:
# 5

# %%
print(ROLL)
# Out:
# 15

# %%
print(Roll)
# Out:
# 10

# %%
x, y = 1,3 
print(x)
# Out:
# 1

# %%
print(x,y)
# Out:
# 1 3

# %%
print(y)
# Out:
# 3

# %%
a=b=c=d =10
print(a,b,c,d)
# Out:
# 10 10 10 10

# %%
a = b= c=d = "owl"
print(a,b,c,d)
# Out:
# owl owl owl owl

# %%
a,b = 1, "hello"

print(a)
print(b)
# Out:
# 1
# hello

# %%
print(a,b)
# Out:
# 1 hello

# %%
x = 10
print(x)

del x
# Out:
# 10

# %% [markdown]
# Shorthand operators

# %%
a = 10
a = a+1
a += 1

print(a)
# Out:
# 12

# %%
a = 10
a = a-1
a -= 1
print(a)
# Out:
# 8

# %% [markdown]
# IN operator - used in search engines when we search

# %%
print("riya" in ("riya is a good girl"))

print("riya" in "mother is cooking")
# Out:
# True
# False

# %% [markdown]
# Chaining Operators

# %%
x=5 

print(1<x<10)

print(10<x<20)

print(x<10< x*10 <100)

print(10 > x <= 9)

print(5==x >4)
# Out:
# True
# False
# True
# True
# True
