# %%
def add  (a,b):
  ans = a+b
  return(ans)

add(5,6)
# Out:
# 11

# %%
add (11,72)
# Out:
# 83

# %%
add (23,23)
# Out:
# 46

# %%
def sub (a,b):
  ans = a-b
  return(ans)

sub(10,8)
# Out:
# 2

# %%
def discount (cost, d):
  cost = cost - (cost * d)/100
  return(cost)

discount (100, 10)
# Out:
# 90.0

# %%
discount (100,8)
# Out:
# 92.0

# %%
discount(1000373783,34)
# Out:
# 660246696.78

# %%
discount(1200,70)
# Out:
# 360.0

# %%
c = int(input("What is your cost price"))

disc = int(input("what is your discount in percentage ?"))

print("the final discounted price is:" , discount(c,disc))
# Out:
# the final discounted price is: 270.0
