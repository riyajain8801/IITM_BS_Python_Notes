# %%
n = str(input("What is Your name?"))

p = str(input("What is your location?"))

print("Hello", n, "How is the weather in",p,"?")

age = int(input("What is your age?"))

print("Good to know you are", age, "Years old.")
# Out:
# Hello riya How is the weather in delhi ?
# Good to know you are 24 Years old.

# %%
r = int(input("Enter the radius of the circle"))

area = 3.14*r*r

print("Area of the circle with radius",r,"is equal to:", area, "units")
# Out:
# Area of the circle with radius 45 is equal to: 6358.500000000001 units
