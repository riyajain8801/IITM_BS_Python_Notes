# %%
n = 3+2
print(n)
# Out:
# 5

# %%
a = 1
b =2 
print(a+b)
# Out:
# 3

# %%
a = "riya"
b= " 2"
print(a+b)
# Out:
# riya 2

# %%
a = [1,2,3]
b = [4,5,6]

print(a+b)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a = 11
b = 15

n = a/b 
print(n)
# Out:
# 0.7333333333333333

# %%
n = (10+13)*2
print(n)
# Out:
# 46

# %% [markdown]
# Operator precedence

# %%
n = 10+13*2
print(n)
# Out:
# 36
