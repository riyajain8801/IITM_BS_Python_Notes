# %%
n = int(input("please enter your number for table: "))

m = int(input("Upto which number you want to get your multiplication table: "))


for i in range (1, m+1):
  print(n, "*", i, "=", n*i)
# Out:
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
