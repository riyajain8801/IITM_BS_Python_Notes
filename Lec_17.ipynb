# %%
alpha = 'abcdefghijklmnopqrstuvwxyz'

i = 1

print(alpha[i])
print(alpha[i+1])
print(alpha[i+2])
print(alpha[i+3])
# Out:
# b
# c
# d
# e

# %%
alpha = 'abcdefghijklmnopqrstuvwxyz'

i = 23

print(alpha[i%26])
print(alpha[(i+1)%26])
print(alpha[(i+2)%26])
print(alpha[(i+3)%26])
# Out:
# x
# y
# z
# a

# %%
r = 'play'

#sjzb

t = ''

i = 0
k = 100

print(alpha[((alpha.index(r[i])+k)%26)])
print(alpha[((alpha.index(r[i+1])+k)%26)])
print(alpha[((alpha.index(r[i+2])+k)%26)])
print(alpha[((alpha.index(r[i+3])+k)%26)])

t = t + (alpha[((alpha.index(r[i])+k)%26)])

t = t + (alpha[((alpha.index(r[i+1])+k)%26)])

t = t + (alpha[((alpha.index(r[i+2])+k)%26)])

t = t + (alpha[((alpha.index(r[i+3])+k)%26)])
print(t)
# Out:
# l
# h
# w
# u
# lhwu
