# %%
for x in range(1, 10):
  if (x % 2) != 0:
    print(x)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(1, 11, 3):
  print(i)
# Out:
# 1
# 4
# 7
# 10

# %%
for i in range (10, -1,-2):
  print(i)
# Out:
# 10
# 8
# 6
# 4
# 2
# 0

# %%
country = 'AMERICA'

for letter in country:
  print(letter)
# Out:
# A
# M
# E
# R
# I
# C
# A
